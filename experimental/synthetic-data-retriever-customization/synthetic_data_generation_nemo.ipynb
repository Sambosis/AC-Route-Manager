# %% [markdown]
# # Retriever Customization - Synthetic Data Generation

# %% [markdown]
# Authors - Aditya Malte, Vinay Raman

# %% [markdown]
# ## Introduction
# Text Retriever/Embedding models serve the purpose of allowing the retrieval of a relevant document given a query. However, they might not perform as well, if the target documents/queries are out-of-domain for the retriever. An example includes retrieving medical documents using a retriever trained only on generic text.

# %% [markdown]
# In these cases, it is often the case that a domain-specific training data must be created to 'adapt' these retrievers. This is often a time-consuming and costly process.

# %% [markdown]
# This notebook is a sample demonstration on how Large Language Models (LLMs) could be used to synthetically generate training data, which can then be used to adapt retriever models.

# %% [markdown]
# ## Overview

# %% [markdown]
# This is the first notebook as part of a two-notebook tutorial. The end-goal of this tutorial is a demo on:
# 1. `synthetic_data_generation_nemo.ipynb`(this notebook) Generating Synthetic Training Data - training examples containing generated queries and positive chunks. The results of which are saved to a `.csv` file, the path of which is printed at the end
# 2. `retriever_customization.ipynb` - Using the generated training data in the `.csv` file to fine-tune a retriever model
#
# NOTE: This tutorial is only meant as a demo, and hence only a small subset of the corpus is used for training data generation - in order for the notebook run to complete in a reasonable time.

# %% [markdown]
# ## Setup Instructions

# %% [markdown]
# 1. This notebook runs in a Docker environment built from the NeMo FW repo. Refer https://github.com/NVIDIA/NeMo/tree/main for instructions on how to build and run the docker containers. Ensure that the docker container you run this notebook in is built from the `main` branch of the `NeMo` repository.
# 2. Update you HuggingFace token to download the Llama model using `export HUGGINGFACE_TOKEN=<yourtoken>`
# 3. Before running this notebook, please run setup.sh to perform the following functions:
#     1. Download the Llama-2-13B Chat model from HuggingFace
#     2. Convert it into a .nemo checkpoint
#     3. Serve the converted model in a Megatron Server
#
# This notebook was tested on a setup comprising 2xA6000 GPUs with CUDA setup. Please ensure you have adequate GPU memory to avoid CUDA out-of-memory issues.

# %% [markdown]
# ## Import Libraries

# %%
import torch
import numpy as np
import os
import json

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
from tqdm import tqdm
import re
import datetime
import re
from nltk.tokenize import sent_tokenize
import nltk
nltk.download('punkt')
from sklearn.model_selection import train_test_split
import requests

# %%
from datasets import load_dataset

# %%
# !pip install rich -q

# %%
# !pip install openai -q
import openai

# %%
# !pip install datasets -q

# %% [markdown]
# As an example, we have chosen the `nfcorpus` to generate training data. You may choose a corpus of your domain, or even feed your own domain data for this process.

# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)
def generate_multiple(texts,do_print=False ):
    port_num = 5555
    headers = {"Content-Type": "application/json"}
    prompts = texts
    data = {
        "sentences": prompts,
        "tokens_to_generate": TOKENS_TO_GENERATE,
        "temperature": TEMPERATURE,
        "add_BOS": False,
        "top_k": TOP_K,
        "top_p": TOP_P,
        "greedy": False,
        "all_probs": False,
        "repetition_penalty": 1.2,
        "min_tokens_to_generate": 50,
        }
    resp = nstruct(json.dumps(data), do_print=do_print)
    return resp
from rich import print as rprint
def pcontent(completion, do_print = True):
    text= (completion.choices[0].message.content)
    if do_print:
        rprint(text)
    return text
def nstruct(prompt, do_print = True):
  completion = client.chat.completions.create(
    model="nvidia/nemotron-4-340b-instruct",
    messages=[{"role":"user","content":prompt}],
    temperature=0.1,
    top_p=0.7,
    max_tokens=500,
    stream=False,
  )
  _ =pcontent(completion, do_print=do_print)
  completion = completion.choices[0].message.content
  return completion
# prompt = "How do I adjust the display so that my picture does not go out of the screen?"
# resp = nstruct(prompt)

# %%
import pandas as pd

splits = {'train': 'train.csv', 'validation': 'dev.csv', 'test': 'test.csv'}
df = pd.read_csv("hf://datasets/kmfoda/booksum/" + splits["train"])

# %%
# DOMAIN = "BeIR/nfcorpus"
# corpus = load_dataset(DOMAIN, "corpus")["corpus"]

# %%
GENERATIONS_SAVE_DIR = "/workspace/files/data"
GENERATION_MODEL_NAME_OR_PATH = "meta-llama/Llama-2-13b-chat-hf"

# %%
DO_SAMPLE=True
TOKENS_TO_GENERATE = 500
TEMPERATURE = 0.1
TOP_P= 0.95
TOP_K= 50

# %% [markdown]
# ## Synthetic Data Generation from Knowledge Base

# %%
def get_prompt(message: str, chat_history: list[tuple[str, str]],
               system_prompt: str) -> str:
    texts = [f'[INST] <<SYS>>\n{system_prompt}\n<</SYS>>\n\n']
    # The first user input is _not_ stripped
    do_strip = False
    for user_input, response in chat_history:
        user_input = user_input.strip() if do_strip else user_input
        do_strip = True
        texts.append(f'{user_input} [/INST] {response.strip()} [INST] ')
    if do_strip:
      print(message)

    message = message.strip() if do_strip else message
    message = "\nDocument 2: \n" + message
    texts.append(f'{message} [/INST]')
    return ''.join(texts)

# %% [markdown]
# ### Chunk Knowledge Base

# %%
dff = df[["book_id", "chapter"]]

# %% [markdown]
# Chunking is required to break large documents into smaller chunks that an LLM can take as input. I this case we chunk the texts into samples of around word count 300, ensuring that sentences are not broken.

# %%
def chunk_text(samples, chunk_size=200):

    final_chunks = []
    for idx, (text, title, paragraph_id) in enumerate(samples):
        sentence_list = sent_tokenize(text)
        chunk = []
        chunk_id = 0
        word_count = 0
        for sentence in sentence_list:
            word_tokens = sentence.split()
            word_count += len(word_tokens)
            chunk.append(sentence)

            if(word_count >= chunk_size):
                chunk_text = " ".join(chunk)
                final_chunks.append((chunk_text, title, paragraph_id, chunk_id))
                chunk_id += 1

                chunk = []
                word_count = 0

        if len(chunk) > 0:
            chunk_text = " ".join(chunk)
            if(chunk_id==0 or len(chunk_text.split())>int((0.4*chunk_size))): # Only include the last chunk if it has significant number of words
                final_chunks.append((chunk_text, title, paragraph_id, chunk_id)) # , or if the sample itself was a single chunk (chunk_id=0)

    return final_chunks

# %%
kb = dff

# %%
# kb = pd.DataFrame(corpus)
kb["paragraph_id"] = range(len(kb))
kb

# %% [markdown]
# As this is just an example notebook, we are only sampling 100 out of around 5000 documents in the corpus, in order to allow the notebook to complete in a reasonable time.

# %%
kb_chunked = pd.DataFrame(chunk_text(kb[["chapter", "book_id", "paragraph_id"]].itertuples(index=False)), columns=["text", "title", "paragraph_id", "chunk_id"])
kb_chunked.columns = ['chunk_text', 'book_id', 'paragraph_id', 'chunk_id']
# kb_chunked.drop(["book_id"], axis=1, inplace=True)
kb_chunked

# %%
# kb = kb.merge(kb_chunked, how="left", on="paragraph_id")
kb = kb_chunked
kb
# Out:
#                                                chunk_text  \
# 0       \n  "Mine ear is open, and my heart prepared:\...
# 1       The facilities which nature had there offered ...
# 2       While, in the pursuit of their daring plans of...
# 3       It was in this scene of strife and bloodshed t...
# 4       [2] A wide frontier had been laid naked by thi...
# ...                                                   ...
# 133459  I must say, I can't help feeling\na sort of co...
# 133460  Sewell was intensely interested in the moral s...
# 133461  He spoke freely of his failure, and with a con...
# 133462  And in your own\ncase, as I understand, you do...
# 133463  "And do you ever have any regrets?" he delicat...
#
#                                        book_id  paragraph_id  chunk_id  \
# 0        The Last of the Mohicans.chapters 1-2             0         0
# 1        The Last of the Mohicans.chapters 1-2             0         1
# 2        The Last of the Mohicans.chapters 1-2             0         2
# 3        The Last of the Mohicans.chapters 1-2             0         3
# 4        The Last of the Mohicans.chapters 1-2             0         4
# ...                                        ...           ...       ...
# 133459  The Rise of Silas Lapham.chapter xxvii          6606        28
# 133460  The Rise of Silas Lapham.chapter xxvii          6606        29
# 133461  The Rise of Silas Lapham.chapter xxvii          6606        30
# 133462  The Rise of Silas Lapham.chapter xxvii          6606        31
# 133463  The Rise of Silas Lapham.chapter xxvii          6606        32
#
#                                   chunk_title_text_concat
# 0       The Last of the Mohicans.chapters 1-2\n\n  "Mi...
# 1       The Last of the Mohicans.chapters 1-2\nThe fac...
# 2       The Last of the Mohicans.chapters 1-2\nWhile, ...
# 3       The Last of the Mohicans.chapters 1-2\nIt was ...
# 4       The Last of the Mohicans.chapters 1-2\n[2] A w...
# ...                                                   ...
# 133459  The Rise of Silas Lapham.chapter xxvii\nI must...
# 133460  The Rise of Silas Lapham.chapter xxvii\nSewell...
# 133461  The Rise of Silas Lapham.chapter xxvii\nHe spo...
# 133462  The Rise of Silas Lapham.chapter xxvii\nAnd in...
# 133463  The Rise of Silas Lapham.chapter xxvii\n"And d...
#
# [133464 rows x 5 columns]

# %%
# kb["title_text_concat"] = kb["book_id"] + "\n" + kb["chapter"]
kb["chunk_title_text_concat"] = kb["book_id"] + "\n" + kb["chunk_text"]

# %% [markdown]
# ## Prompt Generation

# %% [markdown]
# A prompt serves the purpose of providing context to the LLM for generation. You could modify this prompt as per your desired domain
# Some ideas including modifying the example to suit your domain
# The current prompt is used as an examplea and has been picked up from NVIDIA documentation/help page
# You could modify the prompt to represent your desired domain. The queries you give as an example  define the kind of queries the model will generate. In this prompt we ask the LLM to generate three unique questions.

# %%
kb = kb.sample(n=200)
kb
# Out:
#                                                chunk_text  \
# 109343  Jem will be hung, and will go to his father an...
# 83416   I could hear, as well as see, that brandy-face...
# 46141   Mysterious backs\nand ends of houses peeped at...
# 118495  "Slept, Monsieur! When? where?" "You may well ...
# 88763   But, to be sure, he\nwould be idle here--or an...
# ...                                                   ...
# 81711   But although the lists rang with the applauses...
# 111917  But to-night it seemed to Linda there was\nsom...
# 128355  The result was not becoming, to state the case...
# 120659  One could see that, as far as it had gone, her...
# 81842   Yet how should this be, while Rowena, Athelsta...
#
#                                           book_id  paragraph_id  chunk_id  \
# 109343                 Mary Barton.chapters 26-30          5256        43
# 83416           Treasure Island.part 4.chapter 17          3789         3
# 46141       A Tale of Two Cities.book 2.chapter 6          1872        14
# 118495                    Villette.chapters 29-32          5769        50
# 88763                 David Copperfield.chapter x          3923         5
# ...                                           ...           ...       ...
# 81711                          Ivanhoe.chapter 12          3709        13
# 111917                 The Garden Party.chapter 1          5523        54
# 128355            Anne of Green Gables.chapter 27          6270        10
# 120659  The Return of the Native.book 3.chapter 3          5941        16
# 81842                      Ivanhoe.chapters 20-21          3713        25
#
#                                   chunk_title_text_concat
# 109343  Mary Barton.chapters 26-30\nJem will be hung, ...
# 83416   Treasure Island.part 4.chapter 17\nI could hea...
# 46141   A Tale of Two Cities.book 2.chapter 6\nMysteri...
# 118495  Villette.chapters 29-32\n"Slept, Monsieur! Whe...
# 88763   David Copperfield.chapter x\nBut, to be sure, ...
# ...                                                   ...
# 81711   Ivanhoe.chapter 12\nBut although the lists ran...
# 111917  The Garden Party.chapter 1\nBut to-night it se...
# 128355  Anne of Green Gables.chapter 27\nThe result wa...
# 120659  The Return of the Native.book 3.chapter 3\nOne...
# 81842   Ivanhoe.chapters 20-21\nYet how should this be...
#
# [200 rows x 5 columns]

# %%
system_prompt = """You are a data designer trying to generate 2 possible Scenarios that could take place after the passage in Document 2.
Each Scenario must contain an Action and the State of the scene post action.
The Action must be an active decision, choice or movement taken by the focal character in the passage, and it should be concise and limited to a phrase.
The State should be a technical description of the scene, setting, or character immediately after the action is completed, focusing on the changes caused by the action and the resulting condition of the relevant elements in the scene.
The State should be 2 to 4 sentences. DO NOT continue the storyline, use a literary tone, or add additional new actions in the State description. Use a neutral, descriptive tone without literary or emotional language.
Each of the 2 Actions must be enclosed within the <a> and </a> tags, and each 2 generated States must be enclosed in <s> and </s> tags, as shown in the example below:"""
example = """Example:
Time passed like molasses through the hourglass—but it did pass. Thirty minutes left before midnight. Fifteen minutes. Beads of sweat accumulated on my brow. Ten. Five. Three.
I got up briefly to stretch my sleeping legs, and right at that moment something erupted from the cabinet next to me, which I could have sworn I had checked.
Olaf jumped out. Olaf, the valiant defender of the stars, had somehow found a way in and he held a butcher knife in his hands. He fell heavily on the bundle I was ostensibly protecting, preternaturally quickly, so that I had no time to react. He stabbed the bundle over and over and over again. I screamed.
Olaf stopped as suddenly as he had started. There was no blood on the knife. The bundle was empty. He turned to me, but I was already gone, frantically pulling out the nails on the board I had used to condemn the door leading to the stairs.
Generated Scenarios:
Scenario 1:
<a>Olaf jumps out of the cabinet.</a>
<s>Olaf is now standing outside the cabinet, holding a butcher knife in his hands. The cabinet door is open, revealing an empty interior space. Olaf's feet are firmly planted on the floor, and his arms are extended, with the knife gripped tightly in his hands. The narrator is positioned nearby, their body frozen in a state of surprise and fear. The bundle remains on the floor, untouched and intact.</s>
Scenario 2:
<a>The narrator pulls out the last nail from the board on the door.</a>
<s>The board is now completely detached from the door frame, with all the nails removed and scattered on the floor around the narrator's feet. The narrator's hand is gripping the tool used to remove the nails, their knuckles white from the tight grip. The door is no longer obstructed by the board, and a small gap is visible between the door and the frame. The stairs leading down are partially visible through the gap, illuminated by a faint light source from below. </s>
"""
system_prompt += example
system_prompt += "Do not use text from Example to generate queries for Document 2. Only Produce 2 Scenario's"
print(system_prompt)
# Out:
# You are a data designer trying to generate 2 possible Scenarios that could take place after the passage in Document 2.
# Each Scenario must contain an Action and the State of the scene post action.
# The Action must be an active decision, choice or movement taken by the focal character in the passage, and it should be concise and limited to a phrase.
# The State should be a technical description of the scene, setting, or character immediately after the action is completed, focusing on the changes caused by the action and the resulting condition of the relevant elements in the scene.
# The State should be 2 to 4 sentences. DO NOT continue the storyline, use a literary tone, or add additional new actions in the State description. Use a neutral, descriptive tone without literary or emotional language.
# Each of the 2 Actions must be enclosed within the <a> and </a> tags, and each 2 generated States must be enclosed in <s> and </s> tags, as shown in the example below:Example:
# Time passed like molasses through the hourglass—but it did pass. Thirty minutes left before midnight. Fifteen minutes. Beads of sweat accumulated on my brow. Ten. Five. Three. I got up briefly to stretch my sleeping legs, and right at that moment something erupted from the cabinet next to me, which I could have sworn I had checked.
# Olaf jumped out. Olaf, the valiant defender of the stars, had somehow found a way in and he held a butcher knife in his hands. He fell heavily on the bundle I was ostensibly protecting, preternaturally quickly, so that I had no time to react. He stabbed the bundle over and over and over again. I screamed.
# Olaf stopped as suddenly as he had started. There was no blood on the knife. The bundle was empty. He turned to me, but I was already gone, frantically pulling out the nails on the board I had used to condemn the door leading to the stairs.
# Generated Scenarios:
# Scenario 1:
# <a>Olaf jumps out of the cabinet.</a>
# <s>Olaf is now standing outside the cabinet, holding a butcher knife in his hands. The cabinet door is open, revealing an empty interior space. Olaf's feet are firmly planted on the floor, and his arms are extended, with the knife gripped tightly in his hands. The narrator is positioned nearby, their body frozen in a state of surprise and fear. The bundle remains on the floor, untouched and intact.</s>
# Scenario 2:
# <a>The narrator pulls out the last nail from the board on the door.</a>
# <s>The board is now completely detached from the door frame, with all the nails removed and scattered on the floor around the narrator's feet. The narrator's hand is gripping the tool used to remove the nails, their knuckles white from the tight grip. The door is no longer obstructed by the board, and a small gap is visible between the door and the frame. The stairs leading down are partially visible through the gap, illuminated by a faint light source from below. </s>
# Do not use text from Example to generate queries for Document 2. Only Produce 2 Scenario's

# %%
# drop the prompt column
if "chunk_text" in kb.columns:
  kb = kb.drop(["chunk_text"], axis=1)
kb["prompt"] = kb["chunk_title_text_concat"].apply(get_prompt, system_prompt=system_prompt, chat_history="")

# %% [markdown]
# ## Synthetic Data Generation

# %% [markdown]
# This is the function used to generate examples

# %%
import time
from tqdm import tqdm
texts = kb["prompt"].tolist()
len_texts = len(texts)
generations = []

for i in tqdm(range(len_texts)):
    #st_time = time.time()
    resp = generate_multiple([texts[i]], do_print = False)
    # print(resp
    generations.extend([resp])
    # print(f'Completed batch --> {i} out of {len_texts+1}')
    # print('Time for batch = {:.2f} s'.format(time.time() - st_time))
# Out:
# 100%|██████████| 200/200 [1:18:38<00:00, 23.59s/it]

# %%
print(f"Len of Generation: {len(generations)} Len of kb: {len(kb)}")
kb["generated_text"] = generations
# Out:
# Len of Generation: 200 Len of kb: 200

# %% [markdown]
# ## Parsing generations

# %% [markdown]
# Parse the generations to extract the generate queries.

# %%
import pandas as pd
import re

def extract_questions_from_generations(kb):
    paragraph_id_action_state = []

    for row in kb.to_dict(orient='records'):
        paragraph_id = row["paragraph_id"]
        chunk_id = row["chunk_id"]
        print(row["generated_text"])

        actions = re.findall(r'<a>(.+?)</a>', row["generated_text"])
        states = re.findall(r'<s>(.+?)</s>', row["generated_text"])
        print(actions)
        print(states)
        print("-"*200)

        # Ensure the lists are of the same length by filling the shorter one with None
        max_length = max(len(actions), len(states))
        actions += [None] * (max_length - len(actions))
        states += [None] * (max_length - len(states))

        # Combine actions and states in the same row
        paragraph_id_action_state += [(paragraph_id, chunk_id, action, state) for action, state in zip(actions, states)]

    df_combined = pd.DataFrame(paragraph_id_action_state, columns=["paragraph_id", "chunk_id", "chunk_action", "chunk_state"])

    return df_combined

# %%
extracted_questions = extract_questions_from_generations(kb)
kb = kb.merge(extracted_questions, how="left", left_on=["paragraph_id", "chunk_id"], right_on=["paragraph_id", "chunk_id"])
kb.head()
# Out:
# Scenario 1:
# <a>Job steps outside into the pitch darkness.</a>
# <s>Job is now standing outside the house, with the door slightly ajar behind him. The night is quiet and still, with no moonlight to illuminate the surroundings. Job's figure is barely visible in the darkness, and he seems to be looking around, as if trying to get his bearings or searching for something in the gloom.</s>
#
# Scenario 2:
# <a>The widow goes to bed, leaving Jem's fate in the hands of others.</a>
# <s>The widow is now lying in bed, her face pale and drawn with worry and exhaustion. The room is dimly lit by a single candle, casting long shadows on the walls. The bedclothes are rumpled and twisted, indicating her restlessness and inability to sleep. The house is quiet, except for the sound of her labored breathing, as she tries to gather her strength for the challenges of the next day.</s>
# ['Job steps outside into the pitch darkness.', "The widow goes to bed, leaving Jem's fate in the hands of others."]
# ["Job is now standing outside the house, with the door slightly ajar behind him. The night is quiet and still, with no moonlight to illuminate the surroundings. Job's figure is barely visible in the darkness, and he seems to be looking around, as if trying to get his bearings or searching for something in the gloom.", 'The widow is now lying in bed, her face pale and drawn with worry and exhaustion. The room is dimly lit by a single candle, casting long shadows on the walls. The bedclothes are rumpled and twisted, indicating her restlessness and inability to sleep. The house is quiet, except for the sound of her labored breathing, as she tries to gather her strength for the challenges of the next day.']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Trelawney fires the gun at Hands.</a>
# <s>The gun has been fired, and the ball has whistled over Hands, who stooped down just in time to avoid being hit. One of the other four pirates has been struck and has fallen. The echo of the gunshot and the cry of the fallen pirate are still ringing in the air. The boat remains steady, with all hands poised to trim it, and the gun is now pointing in the direction of the shore.</s>
#
# Scenario 2:
# <a>The pirates on the shore begin to row towards the boat.</a>
# <s>The pirates on the shore have tumbled into their boats and have started rowing towards the boat where Trelawney, the captain, and the others are. The oars are dipping into the water in unison, creating a rhythmic sound. The distance between the two groups is gradually decreasing. The pirates' faces are set in determination, and their eyes are fixed on the boat ahead.</s>
# ['Trelawney fires the gun at Hands.', 'The pirates on the shore begin to row towards the boat.']
# ['The gun has been fired, and the ball has whistled over Hands, who stooped down just in time to avoid being hit. One of the other four pirates has been struck and has fallen. The echo of the gunshot and the cry of the fallen pirate are still ringing in the air. The boat remains steady, with all hands poised to trim it, and the gun is now pointing in the direction of the shore.', "The pirates on the shore have tumbled into their boats and have started rowing towards the boat where Trelawney, the captain, and the others are. The oars are dipping into the water in unison, creating a rhythmic sound. The distance between the two groups is gradually decreasing. The pirates' faces are set in determination, and their eyes are fixed on the boat ahead."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Mr. Darnay asks Doctor Manette about his visits to the Tower of London.</a>
# <s>Doctor Manette's expression turns thoughtful as he considers the question. His eyes lose focus momentarily, and he seems to be looking into the past. Lucie watches him with a concerned gaze, her hand still resting on his shoulder. The atmosphere under the plane-tree becomes slightly tense as they await Doctor Manette's response.</s>
#
# Scenario 2:
# <a>Miss Pross retires into the house, experiencing a fit of the jerks.</a>
# <s>Miss Pross's sudden departure leaves a brief silence in her wake. Doctor Manette and Lucie exchange worried glances, but they do not follow her inside. The conversation between Doctor Manette and Mr. Darnay continues, albeit with a slight distraction as they occasionally glance towards the house. The plane-tree leaves rustle gently above them, and the backs of the houses remain silent witnesses to their discussion.</s>
# ['Mr. Darnay asks Doctor Manette about his visits to the Tower of London.', 'Miss Pross retires into the house, experiencing a fit of the jerks.']
# ["Doctor Manette's expression turns thoughtful as he considers the question. His eyes lose focus momentarily, and he seems to be looking into the past. Lucie watches him with a concerned gaze, her hand still resting on his shoulder. The atmosphere under the plane-tree becomes slightly tense as they await Doctor Manette's response.", "Miss Pross's sudden departure leaves a brief silence in her wake. Doctor Manette and Lucie exchange worried glances, but they do not follow her inside. The conversation between Doctor Manette and Mr. Darnay continues, albeit with a slight distraction as they occasionally glance towards the house. The plane-tree leaves rustle gently above them, and the backs of the houses remain silent witnesses to their discussion."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>M. Paul offers to be a careful friend to Miss Lucy.</a>
# <s>M. Paul is now standing closer to Miss Lucy, with a serious and concerned expression on his face. Miss Lucy appears surprised but attentive, her eyes fixed on M. Paul. The atmosphere in the room has shifted, becoming more intimate and focused. The shawls that covered Miss Lucy during her sleep are now folded neatly on the desk, and the desk itself is tidy, with no signs of the previous night's makeshift pillow.</s>
#
# Scenario 2:
# <a>Miss Lucy asserts her independence in response to M. Paul's offer.</a>
# <s>Miss Lucy stands taller, her posture reflecting a newfound determination. She looks directly at M. Paul, her expression firm yet respectful. M. Paul's eyebrows are raised, and he seems taken aback by her response. The room is quiet, filled with the tension of their exchange. The shawls on the desk remain undisturbed, and the desk itself serves as a silent witness to the conversation between the two characters.</s>
# ["The narrator is now standing still, having turned around to face the direction of Rest-and-be-Thankful. Alan is visible in the distance, his figure growing smaller as the narrator continues to watch. The city of Edinburgh and its bustling streets are now behind the narrator, the sounds of the crowd fading away. The narrator's expression is one of longing and sadness, their hand still raised in a gesture of farewell.", "The narrator is now walking with determination through the streets of Edinburgh, following the directions given to them. The crowds of people and the tall buildings no longer hold the same fascination as before. Instead, the narrator's focus is on finding the lawyer's address and completing their mission. The narrator's face is set in a resolute expression, their steps quick and purposeful as they navigate the unfamiliar city."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>The Knave refuses to sign the letter.</a>
# <s>The Knave stands firm, with his arms crossed and a defiant look on his face. The letter remains unsigned on the table in front of him. The King and Queen look angry and frustrated, while the jury members appear confused. Alice watches the scene, her expression showing a mix of curiosity and disbelief.</s>
#
# Scenario 2:
# <a>Alice interrupts the Queen's interpretation of the letter.</a>
# <s>Alice is now standing, her hands on her hips, looking directly at the Queen. The Queen appears taken aback, her mouth open in surprise. The King and the jury members turn to look at Alice, their expressions ranging from shock to interest. The White Rabbit, who was reading the letter, has stopped and is now looking at Alice, his spectacles perched on the end of his nose.</s>
# ['The Knave refuses to sign the letter.', "Alice interrupts the Queen's interpretation of the letter."]
# ['The Knave stands firm, with his arms crossed and a defiant look on his face. The letter remains unsigned on the table in front of him. The King and Queen look angry and frustrated, while the jury members appear confused. Alice watches the scene, her expression showing a mix of curiosity and disbelief.', 'Alice is now standing, her hands on her hips, looking directly at the Queen. The Queen appears taken aback, her mouth open in surprise. The King and the jury members turn to look at Alice, their expressions ranging from shock to interest. The White Rabbit, who was reading the letter, has stopped and is now looking at Alice, his spectacles perched on the end of his nose.']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Maisie admits to not attending to the beast's words about her mother.</a>
# <s>Sir Claude is now walking ahead of Maisie, his back turned to her, with a cloud of smoke surrounding him from his intense smoking. His face is set in a frown, and his eyes are focused on the path in front of him. Maisie is a few steps behind, her head down, and her hands clasped in front of her. The atmosphere between them is tense and uncomfortable, with the only sound being the crunching of gravel under their feet.</s>
#
# Scenario 2:
# <a>Sir Claude calls Maisie a dunce for not taking advantage of the chance to learn about her mother.</a>
# <s>Sir Claude is now standing still, facing Maisie, with a look of frustration on his face. His hands are on his hips, and his cigarette is dangling from his lips. Maisie is looking down at the ground, her cheeks flushed with embarrassment and shame. The air around them is thick with tension, and the sound of children playing in the distance only serves to highlight the silence between them. The relationship between Sir Claude and Maisie has shifted, with a new sense of distance and discomfort introduced.</s>
# ["Maisie admits to not attending to the beast's words about her mother.", 'Sir Claude calls Maisie a dunce for not taking advantage of the chance to learn about her mother.']
# ['Sir Claude is now walking ahead of Maisie, his back turned to her, with a cloud of smoke surrounding him from his intense smoking. His face is set in a frown, and his eyes are focused on the path in front of him. Maisie is a few steps behind, her head down, and her hands clasped in front of her. The atmosphere between them is tense and uncomfortable, with the only sound being the crunching of gravel under their feet.', 'Sir Claude is now standing still, facing Maisie, with a look of frustration on his face. His hands are on his hips, and his cigarette is dangling from his lips. Maisie is looking down at the ground, her cheeks flushed with embarrassment and shame. The air around them is thick with tension, and the sound of children playing in the distance only serves to highlight the silence between them. The relationship between Sir Claude and Maisie has shifted, with a new sense of distance and discomfort introduced.']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Passepartout offers mangoes to Aouda.</a>
# <s>Aouda is now holding a few mangoes in her hands, having accepted them from Passepartout. Passepartout's hands are now empty, having transferred the mangoes to Aouda. The remaining mangoes are still in the bag that Passepartout was carrying. Aouda's expression is one of gratitude and delight, as she admires the fruit. The deck of the Rangoon is still and quiet, with only the sound of the waves and the distant conversations of other passengers.</s>
#
# Scenario 2:
# <a>The Rangoon rides out of Singapore harbour.</a>
# <s>The Rangoon is now in open water, having left the harbour behind. The mountains of Malacca are no longer visible, having been replaced by the vast expanse of the ocean. The ship is moving steadily, its engines humming quietly. The passengers are scattered around the deck, some gazing out at the sea, others engaged in quiet conversation. The air is filled with the scent of salt and sea spray, and the only sound is the gentle lapping of the waves against the hull of the ship.</s>
# ['Passepartout offers mangoes to Aouda.', 'The Rangoon rides out of Singapore harbour.']
# ["Aouda is now holding a few mangoes in her hands, having accepted them from Passepartout. Passepartout's hands are now empty, having transferred the mangoes to Aouda. The remaining mangoes are still in the bag that Passepartout was carrying. Aouda's expression is one of gratitude and delight, as she admires the fruit. The deck of the Rangoon is still and quiet, with only the sound of the waves and the distant conversations of other passengers.", 'The Rangoon is now in open water, having left the harbour behind. The mountains of Malacca are no longer visible, having been replaced by the vast expanse of the ocean. The ship is moving steadily, its engines humming quietly. The passengers are scattered around the deck, some gazing out at the sea, others engaged in quiet conversation. The air is filled with the scent of salt and sea spray, and the only sound is the gentle lapping of the waves against the hull of the ship.']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# <a>The boat-builder confirms Ham's possible return by sea.</a>
# <s>The boat-builder holds the lantern up, illuminating his face and the yard behind him. He nods slowly, confirming that Ham might attempt to return by sea. The gate is now locked, and the only sound is the distant lapping of waves against the shore.</s>
#
# <a>The narrator decides to go to Lowestoft to bring Ham back.</a>
# <s>The narrator turns away from the boat-builder and the locked gate, determination in their step. They head towards the inn to quickly finish their dinner before setting out for Lowestoft. The night is dark, and the road ahead is long, but the narrator is focused on their mission to ensure Ham's safety.</s>
# ["The boat-builder confirms Ham's possible return by sea.", 'The narrator decides to go to Lowestoft to bring Ham back.']
# ['The boat-builder holds the lantern up, illuminating his face and the yard behind him. He nods slowly, confirming that Ham might attempt to return by sea. The gate is now locked, and the only sound is the distant lapping of waves against the shore.', "The narrator turns away from the boat-builder and the locked gate, determination in their step. They head towards the inn to quickly finish their dinner before setting out for Lowestoft. The night is dark, and the road ahead is long, but the narrator is focused on their mission to ensure Ham's safety."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Colonel Nixon fires a warning shot with his .44 automatic to disperse the crowd.</a>
# <s>The crowd scatters in all directions, leaving the street empty except for a few stragglers and the line of trucks. The sound of the gunshot echoes through the city, causing a momentary silence. Colonel Nixon stands with his gun still pointed in the air, his face stern and determined. The strike-breaking drivers look shaken but unharmed, and the police officers nearby exchange nervous glances.</s>
#
# Scenario 2:
# <a>Babbitt's friend, Clarence Drum, orders his troops to arrest a group of striking workers for vandalism.</a>
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# <a>Valancourt admits his wrongdoings to Emily.</a>
# <s>Valancourt is now sitting in the chair beside Emily, with tears in his eyes and a remorseful expression on his face. Emily, on the other hand, is visibly emotional but composed, as she listens to his confession. The room is filled with a tense atmosphere, and the only sound that can be heard is the occasional deep and broken sigh from Valancourt.</s>
#
# <a>Emily decides to trust her heart and forgive Valancourt.</a>
# <s>Emily's face now shows a softer expression, as she looks at Valancourt with tenderness and understanding. Valancourt, in turn, looks at her with a glimmer of hope in his eyes. The tension in the room has eased, and the atmosphere is now filled with a sense of relief and reconciliation. However, Emily's decision to trust her heart and forgive Valancourt is not without caution, as she remembers the warnings given to her by Count De Villefort.</s>
# ['Valancourt admits his wrongdoings to Emily.', 'Emily decides to trust her heart and forgive Valancourt.']
# ['Valancourt is now sitting in the chair beside Emily, with tears in his eyes and a remorseful expression on his face. Emily, on the other hand, is visibly emotional but composed, as she listens to his confession. The room is filled with a tense atmosphere, and the only sound that can be heard is the occasional deep and broken sigh from Valancourt.', "Emily's face now shows a softer expression, as she looks at Valancourt with tenderness and understanding. Valancourt, in turn, looks at her with a glimmer of hope in his eyes. The tension in the room has eased, and the atmosphere is now filled with a sense of relief and reconciliation. However, Emily's decision to trust her heart and forgive Valancourt is not without caution, as she remembers the warnings given to her by Count De Villefort."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>George holds up the little token containing the last of Dobbin's pound notes.</a>
# <s>The token, a small netted purse, is now in George's hand, raised in the air for his father to see. The old gentleman's eyes are fixed on the purse, his expression a mix of surprise and concern. The room is quiet, the only sound being the faint rustling of the purse in George's hand. The tension in the air is palpable as George awaits his father's reaction to the near-empty purse.</s>
#
# Scenario 2:
# <a>The old gentleman looks up George's history in the Peerage.</a>
# ...
# ['Jude goes upstairs to wash his face and tidy himself up.', 'Arabella, Jude, and Donn leave the house to get married.']
# ['Jude is now upstairs, standing in front of a mirror, with a clean face and neatly combed hair. The water in the basin is still dripping, and the towel he used to dry his face is slightly damp. The room is quiet, and the only sound is the faint noise of the guests talking downstairs.', 'The front door of the house is now closed, and the three figures of Arabella, Jude, and Donn can be seen walking down the street. The guests are left behind, sitting in the dining room, discussing the unusual situation. The little maid is in the kitchen, preparing breakfast, and the smell of cooking food starts to fill the house.']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>David walks slowly in the playground, looking melancholy.</a>
# <s>David is now standing in the middle of the playground, with a somber expression on his face. The other boys are watching him from the windows, and some have come out to speak to him. David's posture is straight, and he is looking down, deep in thought. The playground is quiet, and the only sound is the distant noise of the school.</s>
#
# Scenario 2:
# <a>David boards the heavy night-coach, the Farmer.</a>
# <s>David is now sitting inside the night-coach, with his belongings stowed away. The coach is dimly lit, and the other passengers are mostly country-people. David's face is turned towards the window, and he is looking out at the dark road. The coach is moving slowly, and the only sound is the creaking of the wheels and the occasional snore of a fellow passenger.</s>
# ['David walks slowly in the playground, looking melancholy.', 'David boards the heavy night-coach, the Farmer.']
# ["David is now standing in the middle of the playground, with a somber expression on his face. The other boys are watching him from the windows, and some have come out to speak to him. David's posture is straight, and he is looking down, deep in thought. The playground is quiet, and the only sound is the distant noise of the school.", "David is now sitting inside the night-coach, with his belongings stowed away. The coach is dimly lit, and the other passengers are mostly country-people. David's face is turned towards the window, and he is looking out at the dark road. The coach is moving slowly, and the only sound is the creaking of the wheels and the occasional snore of a fellow passenger."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>The Black Sluggard charges into the fight.</a>
# <s>The Black Sluggard is now in the midst of the combat, his black horse causing chaos among the other combatants. The Disinherited Knight's opponents are scattered, trying to avoid the powerful charge. The Black Sluggard's shield remains devoid of any device, and his black armor glistens under the sun. The Disinherited Knight is now fighting alongside the Black Sluggard, their combined force changing the tide of the battle.</s>
#
# Scenario 2:
# <a>Prince John orders his knights to intervene and stop the fight.</a>
# <s>Prince John's knights have entered the lists, their presence causing a temporary halt to the combat. The Disinherited Knight and the Black Sluggard are now surrounded by the prince's men. The crowd watches in silence, awaiting the prince's decision. The Disinherited Knight's opponents are using this opportunity to regroup and recover from the Black Sluggard's charge. The atmosphere is tense, as the outcome of the tournament now hangs in the balance.</s>
# ['The Black Sluggard charges into the fight.', 'Prince John orders his knights to intervene and stop the fight.']
# ["The Black Sluggard is now in the midst of the combat, his black horse causing chaos among the other combatants. The Disinherited Knight's opponents are scattered, trying to avoid the powerful charge. The Black Sluggard's shield remains devoid of any device, and his black armor glistens under the sun. The Disinherited Knight is now fighting alongside the Black Sluggard, their combined force changing the tide of the battle.", "Prince John's knights have entered the lists, their presence causing a temporary halt to the combat. The Disinherited Knight and the Black Sluggard are now surrounded by the prince's men. The crowd watches in silence, awaiting the prince's decision. The Disinherited Knight's opponents are using this opportunity to regroup and recover from the Black Sluggard's charge. The atmosphere is tense, as the outcome of the tournament now hangs in the balance."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Jonathan kisses Linda's fingers and leaves to seek his heirs.</a>
# <s>Jonathan is no longer present in the scene, having departed to search for his heirs. Linda remains standing on the darkening grass, her fingers still touching the spot where Jonathan kissed them. The sea continues to breathe softly, and the silver beams of light still illuminate the garden, but the atmosphere is now tinged with a sense of melancholy and longing. The three stools, desks, and inkpots remain in the background, a stark contrast to the natural beauty of the setting.</s>
#
# Scenario 2:
# <a>Linda watches Jonathan leave and notices his age for the first time.</a>
# <s>Linda's gaze follows Jonathan as he walks away, and she notices the silver speckles in his black hair, a sign of his age that she had not seen before. The garden party setting seems to fade into the background as Linda focuses on Jonathan's figure, now appearing taller and more weed-like in the dimming light. The sea's soft breathing and the silver beams of light continue to create a tender and joyful atmosphere, but Linda's thoughts are now occupied with the realization of Jonathan's aging and the passage of time.</s>
# ["Jonathan kisses Linda's fingers and leaves to seek his heirs.", 'Linda watches Jonathan leave and notices his age for the first time.']
# ['Jonathan is no longer present in the scene, having departed to search for his heirs. Linda remains standing on the darkening grass, her fingers still touching the spot where Jonathan kissed them. The sea continues to breathe softly, and the silver beams of light still illuminate the garden, but the atmosphere is now tinged with a sense of melancholy and longing. The three stools, desks, and inkpots remain in the background, a stark contrast to the natural beauty of the setting.', "Linda's gaze follows Jonathan as he walks away, and she notices the silver speckles in his black hair, a sign of his age that she had not seen before. The garden party setting seems to fade into the background as Linda focuses on Jonathan's figure, now appearing taller and more weed-like in the dimming light. The sea's soft breathing and the silver beams of light continue to create a tender and joyful atmosphere, but Linda's thoughts are now occupied with the realization of Jonathan's aging and the passage of time."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Anne turns the glass back to face her.</a>
# <s>The mirror now reflects Anne's image, revealing her short, unevenly cut hair. Her face is set in a determined expression, and her eyes are fixed on her reflection. The room around her is unchanged, with the bed neatly made and the window letting in a soft light. Anne's hands are resting on the dresser, and her shoulders are squared, as if bracing herself for the sight of her altered appearance.</s>
#
# Scenario 2:
# <a>Anne remains silent when Josie Pye insults her.</a>
# <s>Josie Pye is standing in front of Anne, a smirk on her face. Anne's expression is neutral, and she is looking directly at Josie. The other students in the classroom are watching the interaction, some with curiosity and others with sympathy. The teacher is not present. Anne's hands are clasped in front of her, and she is standing tall, despite the insult. The room is quiet, except for the sound of Josie's voice and the rustling of papers on desks.</s>
# ['Anne turns the glass back to face her.', 'Anne remains silent when Josie Pye insults her.']
# ["The mirror now reflects Anne's image, revealing her short, unevenly cut hair. Her face is set in a determined expression, and her eyes are fixed on her reflection. The room around her is unchanged, with the bed neatly made and the window letting in a soft light. Anne's hands are resting on the dresser, and her shoulders are squared, as if bracing herself for the sight of her altered appearance.", "Josie Pye is standing in front of Anne, a smirk on her face. Anne's expression is neutral, and she is looking directly at Josie. The other students in the classroom are watching the interaction, some with curiosity and others with sympathy. The teacher is not present. Anne's hands are clasped in front of her, and she is standing tall, despite the insult. The room is quiet, except for the sound of Josie's voice and the rustling of papers on desks."]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Scenario 1:
# <a>Clym brings the pot of bones home.</a>
# <s>The pot of bones now sits in Clym's study, atop a table. The room is filled with an eerie atmosphere, as the bones are a stark reminder of the past. The pot is made of earthenware, and the bones inside are yellowed with age. Clym is seen examining the bones with a curious expression, his face illuminated by the light of a nearby lamp.</s>
#
# Scenario 2:
# <a>Clym decides to leave the bones at the barrow.</a>
# <s>The barrow remains open, with the hole dug by the workers still visible. The pot of bones is left at the site, surrounded by the other artifacts that were unearthed. The heath is quiet and desolate, with only the wind blowing through the grass. Clym is seen walking away from the barrow, his figure growing smaller in the distance as he leaves the bones behind.</s>
# ['Clym brings the pot of bones home.', 'Clym decides to leave the bones at the barrow.']
# ["The pot of bones now sits in Clym's study, atop a table. The room is filled with an eerie atmosphere, as the bones are a stark reminder of the past. The pot is made of earthenware, and the bones inside are yellowed with age. Clym is seen examining the bones with a curious expression, his face illuminated by the light of a nearby lamp.", 'The barrow remains open, with the hole dug by the workers still visible. The pot of bones is left at the site, surrounded by the other artifacts that were unearthed. The heath is quiet and desolate, with only the wind blowing through the grass. Clym is seen walking away from the barrow, his figure growing smaller in the distance as he leaves the bones behind.']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# <a>Cedric offers a ransom for their freedom to the sewer.</a>
# <s>The sewer stands before Cedric, holding the white rod of office, with a solemn expression on his masked face. Cedric's words hang in the air, as the attendants behind the sewer remain still, their eyes fixed on the Saxon lord. The table with the dishes remains untouched, the aroma of the food filling the room. The atmosphere is tense, as the sewer considers Cedric's offer, and the other prisoners watch in anticipation.</s>
#
# <a>The sewer accepts Cedric's offer and leaves to inform Reginald Front-de-Boeuf.</a>
# <s>The sewer nods once, then turns and exits the chamber, his attendants following closely behind. The door closes with a heavy thud, leaving the prisoners alone once more. Cedric, Rowena, and Athelstane exchange hopeful glances, their spirits lifted by the possibility of their imminent release. The room is quiet, save for the faint sound of footsteps fading away in the distance.</s>
# ['Cedric offers a ransom for their freedom to the sewer.', "The sewer accepts Cedric's offer and leaves to inform Reginald Front-de-Boeuf."]
# ["The sewer stands before Cedric, holding the white rod of office, with a solemn expression on his masked face. Cedric's words hang in the air, as the attendants behind the sewer remain still, their eyes fixed on the Saxon lord. The table with the dishes remains untouched, the aroma of the food filling the room. The atmosphere is tense, as the sewer considers Cedric's offer, and the other prisoners watch in anticipation.", 'The sewer nods once, then turns and exits the chamber, his attendants following closely behind. The door closes with a heavy thud, leaving the prisoners alone once more. Cedric, Rowena, and Athelstane exchange hopeful glances, their spirits lifted by the possibility of their imminent release. The room is quiet, save for the faint sound of footsteps fading away in the distance.']
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#                                  book_id  paragraph_id  chunk_id  \
# 0             Mary Barton.chapters 26-30          5256        43
# 1             Mary Barton.chapters 26-30          5256        43
# 2      Treasure Island.part 4.chapter 17          3789         3
# 3      Treasure Island.part 4.chapter 17          3789         3
# 4  A Tale of Two Cities.book 2.chapter 6          1872        14
#
#                              chunk_title_text_concat  \
# 0  Mary Barton.chapters 26-30\nJem will be hung, ...
# 1  Mary Barton.chapters 26-30\nJem will be hung, ...
# 2  Treasure Island.part 4.chapter 17\nI could hea...
# 3  Treasure Island.part 4.chapter 17\nI could hea...
# 4  A Tale of Two Cities.book 2.chapter 6\nMysteri...
#
#                                               prompt  \
# 0  [INST] <<SYS>>\nYou are a data designer trying...
# 1  [INST] <<SYS>>\nYou are a data designer trying...
# 2  [INST] <<SYS>>\nYou are a data designer trying...
# 3  [INST] <<SYS>>\nYou are a data designer trying...
# 4  [INST] <<SYS>>\nYou are a data designer trying...
#
#                                       generated_text  \
# 0  Scenario 1:\n<a>Job steps outside into the pit...
# 1  Scenario 1:\n<a>Job steps outside into the pit...
# 2  Scenario 1:\n<a>Trelawney fires the gun at Han...
# 3  Scenario 1:\n<a>Trelawney fires the gun at Han...
# 4  Scenario 1:\n<a>Mr. Darnay asks Doctor Manette...
#
#                                         chunk_action  \
# 0         Job steps outside into the pitch darkness.
# 1  The widow goes to bed, leaving Jem's fate in t...
# 2                  Trelawney fires the gun at Hands.
# 3  The pirates on the shore begin to row towards ...
# 4  Mr. Darnay asks Doctor Manette about his visit...
#
#                                          chunk_state
# 0  Job is now standing outside the house, with th...
# 1  The widow is now lying in bed, her face pale a...
# 2  The gun has been fired, and the ball has whist...
# 3  The pirates on the shore have tumbled into the...
# 4  Doctor Manette's expression turns thoughtful a...

# %%
qa_pairs = kb[["chunk_action", "chunk_state", "chunk_title_text_concat", "chunk_id", "paragraph_id"]]
qa_pairs.columns = ["action", "state", "positive_chunk", "positive_chunk_id", "paragraph_id"]
qa_pairs
# Out:
#                                                 action  \
# 0           Job steps outside into the pitch darkness.
# 1    The widow goes to bed, leaving Jem's fate in t...
# 2                    Trelawney fires the gun at Hands.
# 3    The pirates on the shore begin to row towards ...
# 4    Mr. Darnay asks Doctor Manette about his visit...
# ..                                                 ...
# 395    Anne remains silent when Josie Pye insults her.
# 396                 Clym brings the pot of bones home.
# 397     Clym decides to leave the bones at the barrow.
# 398  Cedric offers a ransom for their freedom to th...
# 399  The sewer accepts Cedric's offer and leaves to...
#
#                                                  state  \
# 0    Job is now standing outside the house, with th...
# 1    The widow is now lying in bed, her face pale a...
# 2    The gun has been fired, and the ball has whist...
# 3    The pirates on the shore have tumbled into the...
# 4    Doctor Manette's expression turns thoughtful a...
# ..                                                 ...
# 395  Josie Pye is standing in front of Anne, a smir...
# 396  The pot of bones now sits in Clym's study, ato...
# 397  The barrow remains open, with the hole dug by ...
# 398  The sewer stands before Cedric, holding the wh...
# 399  The sewer nods once, then turns and exits the ...
#
#                                         positive_chunk  positive_chunk_id  \
# 0    Mary Barton.chapters 26-30\nJem will be hung, ...                 43
# 1    Mary Barton.chapters 26-30\nJem will be hung, ...                 43
# 2    Treasure Island.part 4.chapter 17\nI could hea...                  3
# 3    Treasure Island.part 4.chapter 17\nI could hea...                  3
# 4    A Tale of Two Cities.book 2.chapter 6\nMysteri...                 14
# ..                                                 ...                ...
# 395  Anne of Green Gables.chapter 27\nThe result wa...                 10
# 396  The Return of the Native.book 3.chapter 3\nOne...                 16
# 397  The Return of the Native.book 3.chapter 3\nOne...                 16
# 398  Ivanhoe.chapters 20-21\nYet how should this be...                 25
# 399  Ivanhoe.chapters 20-21\nYet how should this be...                 25
#
#      paragraph_id
# 0            5256
# 1            5256
# 2            3789
# 3            3789
# 4            1872
# ..            ...
# 395          6270
# 396          5941
# 397          5941
# 398          3713
# 399          3713
#
# [400 rows x 5 columns]

# %% [markdown]
# ## Save the results

# %%
GENERATIONS_SAVE_FILENAME =  f"qa_pairs_{GENERATION_MODEL_NAME_OR_PATH}_num_questions_{len(qa_pairs)}_{DOMAIN}"
GENERATIONS_SAVE_FILENAME = re.sub(r'\W+', '_', GENERATIONS_SAVE_FILENAME)
GENERATIONS_SAVE_PATH = os.path.join(GENERATIONS_SAVE_DIR, f"{GENERATIONS_SAVE_FILENAME}.csv")

# %%
kb.to_csv("/content/drive/MyDrive/syndata.csv", mode='a', index=None, header=None)
kb.to_csv("./syndata.csv", mode='a', index=None, header=None)
print(f"Generated QA Pairs saved to {GENERATIONS_SAVE_PATH}")
# Out:
# Generated QA Pairs saved to /workspace/files/data/qa_pairs_meta_llama_Llama_2_13b_chat_hf_num_questions_400_BeIR_nfcorpus.csv
